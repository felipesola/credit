# %% [markdown]
# # Importing Libraries
#
# Importing the main libraries for EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Dataset
#
# Import the data set with the data treated in the collection-cleaning step

# %%
df = pd.read_csv('credit.csv')
df.head(10)
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
# 5   'no checking'        36                   'existing paid'
# 6   'no checking'        24                   'existing paid'
# 7        0<=X<200        36                   'existing paid'
# 8   'no checking'        12                   'existing paid'
# 9        0<=X<200        30  'critical/other existing credit'
#
#                purpose  credit_amount      savings_status  employment  \
# 0             radio/tv           1169  'no known savings'         >=7
# 1             radio/tv           5951                <100      1<=X<4
# 2            education           2096                <100      4<=X<7
# ...

# %% [markdown]
# # Histogram
#
# Ploting the histogram to compare with the one with missing values

# %%
#Setting histogram charts

df.hist(figsize=(12, 8))
plt.subplots_adjust(hspace=0.6)
plt.show()

# %% [markdown]
# # Stripplot of all data
# This is to visualy understand how numerical data is distributed

# %%
plt.figure(figsize = (12,8))
sns.stripplot(data = df, orient='h', palette='mako', jitter = False, size = 1.5)
# Out:
# <Axes: >

# %% [markdown]
# # Boxplot
#
# Of every column

# %%
#Setting boxplot chart

plt.figure(figsize = (12,8))
sns.boxplot(data = df, orient = 'h', fliersize = 1, linewidth = 0.5, palette='mako')
# Out:
# <Axes: >

# %% [markdown]
# # Scatter Plots
#
# Make some analysis with scatter plots

# %%
#Setting scatter

plt.figure(figsize = (12,8))
sns.stripplot(data = df, 
              x='job', 
              y='credit_amount', 
              hue="class", 
              jitter = True, 
              dodge = True, 
              size = 1.5, 
              palette='mako')
# Out:
# <Axes: xlabel='job', ylabel='credit_amount'>

# %%
#Correlation Matrix

#Select only numerical data
df_int = df.select_dtypes(include=['int64'])

#Correlation
corr = df_int.corr()

#Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

#Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

#Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

#Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %% [markdown]
# Here we can see that if the 'Humidity3pm' column value surpass the value 60 it is likely to rain in the next day
